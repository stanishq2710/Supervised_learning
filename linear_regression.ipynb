# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
data = fetch_california_housing(as_frame=True)
df = data.frame
print(df.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
x = df.drop('MedHouseVal',axis=1) #features
y = df['MedHouseVal'] #target

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size =0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error :", mse)
print("R2 score: ", r2)
# mse lower is better
# r^2 closer to 1 means better model fit
# Out:
# Mean Squared Error : 0.5558915986952443
# R2 score:  0.5757877060324508

# %%
plt.scatter(y_test, y_pred, alpha =0.3)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted" )
plt.plot([0,5],[0,5], '--', color= 'red')
plt.show()

# %%
# linear regression model is used when you want to model the relationship between a continous 
# dependent variable and one or more independent variables, and you expect a linear
# relationship between them.
